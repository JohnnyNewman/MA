# %%
from base import *

# %%
import pickle

# %%
dataset = pickle.load(open("save/T007/full_dataset.p", "rb"))
train_dataset = pickle.load(open("save/T007/train_dataset.p", "rb"))
test_dataset = pickle.load(open("save/T007/test_dataset.p", "rb"))

# %%
#model = AirfoilModel(train_dataset, test_dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-78d78d74c0aa> in <module>
# ----> 1 model = AirfoilModel(train_dataset, test_dataset)
#
# TypeError: __init__() takes 1 positional argument but 3 were given

# %%
test_dataset[0]

# %%
y = model()

# %%
ma, aoa, dv, x, y = test_dataset[:]

# %%
PATH = "lightning_logs/version_30/checkpoints/epoch=869.ckpt"
model = AirfoilModel.load_from_checkpoint(PATH, None, None)

# %%
model = model.double().eval()
z = model(x, ma, aoa)

loss = F.mse_loss(z, y)
z = z.detach().numpy()

# %%
loss
# Out:
# tensor(0.2306, dtype=torch.float64, grad_fn=<MseLossBackward>)

# %%
fig, axes = plt.subplots(20, 4, figsize=(16,64))

for k, ax in enumerate(axes.flat):
    i = int(k / 4)
    j = k % 4
    #i = k
    #j = 0
    ax.plot(x[i,0,:], -z[i, j, :], ".")
    ax.plot(x[i,0,:], -y[i, j, :])
    ax.set_title(f"{i}")

# %%
F.mse_loss(z, y)

# %%
# Start tensorboard.
# %load_ext tensorboard
# %tensorboard --logdir lightning_logs/
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 9636), started 2 days, 7:44:07 ago. (Use '!kill 9636' to kill it.)
#       <iframe id="tensorboard-frame-4ac390d7b9dfe0db" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-4ac390d7b9dfe0db");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
